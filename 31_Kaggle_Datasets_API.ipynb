# %%
import pandas as pd

dataframe = pd.read_csv("E:\\Data_Scientist\\Skill_Share(DataScienceCourse)\\Datasets\\31_Breast_CancerDataset.csv")
dataframe.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
dataframe.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
df = dataframe.rename(columns = {'diagnosis': 'Diagonosis/Names'}, inplace = False)

# %%
df.head()

# %%
#Install kaggle API

pip install kaggle

# %%
import os
os.environ['KAGGLE_USERNAME'] = "wajidlinux" #username from json file
os.environ['KAGGLE_KEY'] = "f1f94067f8c3ff8a6695fe3832a73584" #key from json file

# !kaggle competitions download -c dogs-vs-cats
# Out:
# ...
#   0%|          | 0.00/812M [00:00<?, ?B/s]
#   0%|          | 1.00M/812M [00:00<08:30, 1.67MB/s]
#   0%|          | 2.00M/812M [00:01<11:20, 1.25MB/s]
#   0%|          | 3.00M/812M [00:03<12:14, 1.15MB/s]
#   0%|          | 4.00M/812M [00:04<13:57, 1.01MB/s]
#   1%|          | 5.00M/812M [00:05<13:33, 1.04MB/s]
#   1%|          | 6.00M/812M [00:06<14:13, 990kB/s]
#   1%|          | 7.00M/812M [00:07<14:52, 946kB/s]
#   1%|          | 8.00M/812M [00:08<14:56, 941kB/s]
#   1%|1         | 9.00M/812M [00:09<14:54, 941kB/s]
#   1%|1         | 10.0M/812M [00:11<14:49, 946kB/s]
#   1%|1         | 11.0M/812M [00:12<14:58, 935kB/s]
#   1%|1         | 12.0M/812M [00:13<15:09, 922kB/s]
#   2%|1         | 13.0M/812M [00:14<14:48, 943kB/s]
#   2%|1         | 14.0M/812M [00:15<14:55, 934kB/s]
#   2%|1         | 15.0M/812M [00:16<15:48, 881kB/s]
#   2%|1         | 16.0M/812M [00:17<14:16, 975kB/s]
#   2%|2         | 17.0M/812M [00:18<14:11, 979kB/s]
# ...

# %%
#to unzip main file 
from zipfile  import ZipFile
dataset_name = "E:\Data_Scientist\Skill_Share(DataScienceCourse)/dogs-vs-cats.zip"

with ZipFile(dataset_name, 'r') as zip:
    zip.extractall()
    print("Done")
# Out:
# Done

# %%
#to unzip test file 
from zipfile  import ZipFile
dataset_name = "E:\Data_Scientist\Skill_Share(DataScienceCourse)\Datasets\Kaggle API/test1.zip"

with ZipFile(dataset_name, 'r') as zip:
    zip.extractall()
    print("Done")
# Out:
# Done

# %%
#to unzip trainfile 
from zipfile  import ZipFile
dataset_name = "E:\Data_Scientist\Skill_Share(DataScienceCourse)\Datasets\Kaggle API/train.zip"

with ZipFile(dataset_name, 'r') as zip:
    zip.extractall()
    print("Done")
# Out:
# Done

# %%
#??????????????????????

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
