# %%
import pandas as pd

# %%
dataSet = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv")
dataSet.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
dataSet.shape
# Out:
# (173, 21)

# %%
#dataSet.dropna( will simply remove every null col)

dataSet.isnull().sum()
# Out:
# Rank                    0
# Major_code              0
# Major                   0
# Total                   1
# Men                     1
# Women                   1
# Major_category          0
# ShareWomen              1
# Sample_size             0
# Employed                0
# Full_time               0
# Part_time               0
# Full_time_year_round    0
# Unemployed              0
# Unemployment_rate       0
# Median                  0
# P25th                   0
# P75th                   0
# College_jobs            0
# Non_college_jobs        0
# Low_wage_jobs           0
# dtype: int64

# %%
# return any col with missing data
dataSet[dataSet.isnull().any(axis=1)]
# Out:
#     Rank  Major_code         Major  Total  Men  Women  \
# 21    22        1104  FOOD SCIENCE    NaN  NaN    NaN
#
#                      Major_category  ShareWomen  Sample_size  Employed  ...  \
# 21  Agriculture & Natural Resources         NaN           36      3149  ...
#
#     Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 21       1121                  1735         338           0.096931   53000
#
#     P25th  P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 21  32000  70000          1183              1274            485
#
# [1 rows x 21 columns]

# %% [markdown]
# # Method1: Boolean Mask

# %%
#tell what condition u want if its true
#filter for one condiiton
df1 = dataSet[dataSet['Major_category']== 'Social Science']
df1
# Out:
#      Rank  Major_code                              Major     Total      Men  \
# 36     37        5501                          ECONOMICS  139247.0  89749.0
# 56     57        5505            INTERNATIONAL RELATIONS   28187.0  10345.0
# 68     69        5599      MISCELLANEOUS SOCIAL SCIENCES    3283.0   1499.0
# 78     79        5506   POLITICAL SCIENCE AND GOVERNMENT  182621.0  93880.0
# 79     80        5504                          GEOGRAPHY   18480.0  11404.0
# 102   103        5503                        CRIMINOLOGY   19879.0  10031.0
# 124   125        5507                          SOCIOLOGY  115433.0  32510.0
# 131   132        4007  INTERDISCIPLINARY SOCIAL SCIENCES    9916.0   2337.0
# 142   143        5500            GENERAL SOCIAL SCIENCES   12920.0   5079.0
#
#        Women  Major_category  ShareWomen  Sample_size  Employed  ...  \
# 36   49498.0  Social Science    0.355469         1322    104117  ...
# ...

# %%
#filter for more than one condiiton
#just use appranthsis not square brackets
df1M = dataSet[(dataSet['Major_category']== 'Social Science') 
               &
               (dataSet['ShareWomen']>=.5)]
df1M
# Out:
#      Rank  Major_code                              Major     Total      Men  \
# 56     57        5505            INTERNATIONAL RELATIONS   28187.0  10345.0
# 68     69        5599      MISCELLANEOUS SOCIAL SCIENCES    3283.0   1499.0
# 124   125        5507                          SOCIOLOGY  115433.0  32510.0
# 131   132        4007  INTERDISCIPLINARY SOCIAL SCIENCES    9916.0   2337.0
# 142   143        5500            GENERAL SOCIAL SCIENCES   12920.0   5079.0
#
#        Women  Major_category  ShareWomen  Sample_size  Employed  ...  \
# 56   17842.0  Social Science    0.632987          219     21190  ...
# 68    1784.0  Social Science    0.543405           28      2727  ...
# 124  82923.0  Social Science    0.718365         1024     92721  ...
# 131   7579.0  Social Science    0.764320           95      7444  ...
# 142   7841.0  Social Science    0.606889          113      9602  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
#use of ~ will produce exatly opposite of something or datframe

# %% [markdown]
# # Method2: Loc

# %%
df2 = dataSet.loc[dataSet['Major_category']== 'Social Science']
df2
# Out:
#      Rank  Major_code                              Major     Total      Men  \
# 36     37        5501                          ECONOMICS  139247.0  89749.0
# 56     57        5505            INTERNATIONAL RELATIONS   28187.0  10345.0
# 68     69        5599      MISCELLANEOUS SOCIAL SCIENCES    3283.0   1499.0
# 78     79        5506   POLITICAL SCIENCE AND GOVERNMENT  182621.0  93880.0
# 79     80        5504                          GEOGRAPHY   18480.0  11404.0
# 102   103        5503                        CRIMINOLOGY   19879.0  10031.0
# 124   125        5507                          SOCIOLOGY  115433.0  32510.0
# 131   132        4007  INTERDISCIPLINARY SOCIAL SCIENCES    9916.0   2337.0
# 142   143        5500            GENERAL SOCIAL SCIENCES   12920.0   5079.0
#
#        Women  Major_category  ShareWomen  Sample_size  Employed  ...  \
# 36   49498.0  Social Science    0.355469         1322    104117  ...
# ...

# %%
df2M = dataSet.loc[(dataSet['Major_category']== 'Social Science') 
               &
               (dataSet['ShareWomen']>=.5)]
df2M
# Out:
#      Rank  Major_code                              Major     Total      Men  \
# 56     57        5505            INTERNATIONAL RELATIONS   28187.0  10345.0
# 68     69        5599      MISCELLANEOUS SOCIAL SCIENCES    3283.0   1499.0
# 124   125        5507                          SOCIOLOGY  115433.0  32510.0
# 131   132        4007  INTERDISCIPLINARY SOCIAL SCIENCES    9916.0   2337.0
# 142   143        5500            GENERAL SOCIAL SCIENCES   12920.0   5079.0
#
#        Women  Major_category  ShareWomen  Sample_size  Employed  ...  \
# 56   17842.0  Social Science    0.632987          219     21190  ...
# 68    1784.0  Social Science    0.543405           28      2727  ...
# 124  82923.0  Social Science    0.718365         1024     92721  ...
# 131   7579.0  Social Science    0.764320           95      7444  ...
# 142   7841.0  Social Science    0.606889          113      9602  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
#loc to get specfic column
df3 = dataSet.loc[(dataSet['Major_category']== 'Social Science') 
               &
               (dataSet['ShareWomen']>=.5),'Part_time']
df3.head()
# Out:
# 56      5563
# 68       907
# 124    29639
# 131     2834
# 142     3396
# Name: Part_time, dtype: int64

# %%
#loc to get specfic multiple column
col=['Part_time','Total']
df3m = dataSet.loc[(dataSet['Major_category']== 'Social Science') 
               &
               (dataSet['ShareWomen']>=.5),col]
df3m.head()
# Out:
#      Part_time     Total
# 56        5563   28187.0
# 68         907    3283.0
# 124      29639  115433.0
# 131       2834    9916.0
# 142       3396   12920.0

# %%
#to get specific number of rows wih specific col name
dfS = dataSet.loc[dataSet.index[:10], ['Major','Major_category']]
dfS
# Out:
#                                        Major     Major_category
# 0                      PETROLEUM ENGINEERING        Engineering
# 1             MINING AND MINERAL ENGINEERING        Engineering
# 2                  METALLURGICAL ENGINEERING        Engineering
# 3  NAVAL ARCHITECTURE AND MARINE ENGINEERING        Engineering
# 4                       CHEMICAL ENGINEERING        Engineering
# 5                        NUCLEAR ENGINEERING        Engineering
# 6                          ACTUARIAL SCIENCE           Business
# 7                 ASTRONOMY AND ASTROPHYSICS  Physical Sciences
# 8                     MECHANICAL ENGINEERING        Engineering
# 9                     ELECTRICAL ENGINEERING        Engineering

# %%
# to replace index with a col
dfI = dataSet.set_index(dataSet['Major'])
dfI
# Out:
#                                            Rank  Major_code  \
# Major
# PETROLEUM ENGINEERING                         1        2419
# MINING AND MINERAL ENGINEERING                2        2416
# METALLURGICAL ENGINEERING                     3        2415
# NAVAL ARCHITECTURE AND MARINE ENGINEERING     4        2417
# CHEMICAL ENGINEERING                          5        2405
# ...                                         ...         ...
# ZOOLOGY                                     169        3609
# EDUCATIONAL PSYCHOLOGY                      170        5201
# CLINICAL PSYCHOLOGY                         171        5202
# COUNSELING PSYCHOLOGY                       172        5203
# LIBRARY SCIENCE                             173        3501
#
#                                                                                Major  \
# Major
# PETROLEUM ENGINEERING                                          PETROLEUM ENGINEERING
# ...

# %%
rows = ['ZOOLOGY','LIBRARY SCIENCE']
col = ['Major_code','Total']

dfN = dfI.loc[rows,col]
dfN
# Out:
#                  Major_code   Total
# Major
# ZOOLOGY                3609  8409.0
# LIBRARY SCIENCE        3501  1098.0

# %% [markdown]
# # Method3: Query

# %%
dfq = dataSet.query("Major_category == 'Social Science' & ShareWomen >=.5", inplace=False)
dfq.head()
# Out:
#      Rank  Major_code                              Major     Total      Men  \
# 56     57        5505            INTERNATIONAL RELATIONS   28187.0  10345.0
# 68     69        5599      MISCELLANEOUS SOCIAL SCIENCES    3283.0   1499.0
# 124   125        5507                          SOCIOLOGY  115433.0  32510.0
# 131   132        4007  INTERDISCIPLINARY SOCIAL SCIENCES    9916.0   2337.0
# 142   143        5500            GENERAL SOCIAL SCIENCES   12920.0   5079.0
#
#        Women  Major_category  ShareWomen  Sample_size  Employed  ...  \
# 56   17842.0  Social Science    0.632987          219     21190  ...
# 68    1784.0  Social Science    0.543405           28      2727  ...
# 124  82923.0  Social Science    0.718365         1024     92721  ...
# 131   7579.0  Social Science    0.764320           95      7444  ...
# 142   7841.0  Social Science    0.606889          113      9602  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
#how to check speed test?
#use mask  if all columnss u want

# %timeit dataSet[(dataSet['Major_category']== 'Social Science') &(dataSet['ShareWomen']>=.5)]
#use loc if specific col u want
# %timeit dataSet.loc[(dataSet['Major_category']== 'Social Science')&(dataSet['ShareWomen']>=.5)]
#dont use Query
# %timeit dataSet.query("Major_category == 'Social Science' & ShareWomen >=.5")
# Out:
# 857 µs ± 13.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 856 µs ± 13.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.58 ms ± 51.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # Method4: iloc

# %%
df4 = dataSet.iloc[:10,2:6] #first 10 rows and col 2 till 5
df4
# Out:
#                                        Major    Total      Men    Women
# 0                      PETROLEUM ENGINEERING   2339.0   2057.0    282.0
# 1             MINING AND MINERAL ENGINEERING    756.0    679.0     77.0
# 2                  METALLURGICAL ENGINEERING    856.0    725.0    131.0
# 3  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0   1123.0    135.0
# 4                       CHEMICAL ENGINEERING  32260.0  21239.0  11021.0
# 5                        NUCLEAR ENGINEERING   2573.0   2200.0    373.0
# 6                          ACTUARIAL SCIENCE   3777.0   2110.0   1667.0
# 7                 ASTRONOMY AND ASTROPHYSICS   1792.0    832.0    960.0
# 8                     MECHANICAL ENGINEERING  91227.0  80320.0  10907.0
# 9                     ELECTRICAL ENGINEERING  81527.0  65511.0  16016.0

# %%
df4 = dataSet.iloc[:10,[2,6]] #first 10 rows and col 2 and 6
df4
# Out:
#                                        Major     Major_category
# 0                      PETROLEUM ENGINEERING        Engineering
# 1             MINING AND MINERAL ENGINEERING        Engineering
# 2                  METALLURGICAL ENGINEERING        Engineering
# 3  NAVAL ARCHITECTURE AND MARINE ENGINEERING        Engineering
# 4                       CHEMICAL ENGINEERING        Engineering
# 5                        NUCLEAR ENGINEERING        Engineering
# 6                          ACTUARIAL SCIENCE           Business
# 7                 ASTRONOMY AND ASTROPHYSICS  Physical Sciences
# 8                     MECHANICAL ENGINEERING        Engineering
# 9                     ELECTRICAL ENGINEERING        Engineering

# %%
dfSss = dataSet.loc[dataSet.index[:], ['Major']]
dfSss
# Out:
#                                          Major
# 0                        PETROLEUM ENGINEERING
# 1               MINING AND MINERAL ENGINEERING
# 2                    METALLURGICAL ENGINEERING
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                         CHEMICAL ENGINEERING
# ..                                         ...
# 168                                    ZOOLOGY
# 169                     EDUCATIONAL PSYCHOLOGY
# 170                        CLINICAL PSYCHOLOGY
# 171                      COUNSELING PSYCHOLOGY
# 172                            LIBRARY SCIENCE
#
# [173 rows x 1 columns]
